# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
import scipy
from scipy import stats

# %%
rank_2014 = "Resources/2014_rankings.csv"

rank_2014 = pd.read_csv(rank_2014, usecols = ['Rank',
                                              'Team'])

rank_2014_df = pd.DataFrame(rank_2014)

rank_2014_df.head(25)
# Out:
#     Rank               Team
# 0      1            Alabama
# 1      2             Oregon
# 2      3      Florida State
# 3      4         Ohio State
# 4      5             Baylor
# 5      6                TCU
# 6      7  Mississippi State
# 7      8     Michigan State
# 8      9           Ole Miss
# 9     10            Arizona
# 10    11       Kansas State
# 11    12       Georgia Tech
# 12    13            Georgia
# 13    14               UCLA
# 14    15      Arizona State
# 15    16           Missouri
# 16    17            Clemson
# 17    18          Wisconsin
# 18    19             Auburn
# 19    20        Boise State
# 20    21         Louisville
# 21    22               Utah
# 22    23                LSU
# 23    24       Southern Cal
# 24    25          Minnesota

# %%
rank_2015 = "Resources/2015_rankings.csv"

rank_2015 = pd.read_csv(rank_2015, usecols = ['Rank',
                                              'Team'])

rank_2015_df = pd.DataFrame(rank_2015)

rank_2015_df.head(25)
# Out:
#     Rank            Team
# 0    1.0         Clemson
# 1    2.0         Alabama
# 2    3.0  Michigan State
# 3    4.0        Oklahoma
# 4    5.0            Iowa
# 5    6.0        Stanford
# 6    7.0      Ohio State
# 7    8.0      Notre Dame
# 8    9.0   Florida State
# 9   10.0  North Carolina
# 10  11.0             TCU
# 11  12.0        Ole Miss
# 12  13.0    Northwestern
# 13  14.0        Michigan
# 14  15.0          Oregon
# 15  16.0  Oklahoma State
# 16  17.0          Baylor
# 17  18.0         Houston
# 18  19.0         Florida
# 19  20.0             LSU
# 20   NaN             NaN
# 21  22.0            Utah
# 22  23.0       Tennessee
# 23  24.0          Temple
# 24  25.0    Southern Cal

# %%
rank_2016 = "Resources/2016_rankings.csv"

rank_2016 = pd.read_csv(rank_2016, usecols = ['Rank',
                                              'Team'])

rank_2016_df = pd.DataFrame(rank_2016)

rank_2016_df.head(25)
# Out:
#     Rank              Team
# 0      1           Alabama
# 1      2           Clemson
# 2      3        Ohio State
# 3      4        Washington
# 4      5        Penn State
# 5      6          Michigan
# 6      7          Oklahoma
# 7      8         Wisconsin
# 8      9      Southern Cal
# 9     10          Colorado
# 10    11     Florida State
# 11    12    Oklahoma State
# 12    13        Louisville
# 13    14            Auburn
# 14    15  Western Michigan
# 15    16     West Virginia
# 16    17           Florida
# 17    18          Stanford
# 18    19              Utah
# 19    20               LSU
# 20    21         Tennessee
# 21    22     Virginia Tech
# 22    23              Pitt
# 23    24            Temple

# %%
rank_2017 = "Resources/2017_rankings.csv"

rank_2017 = pd.read_csv(rank_2017, usecols = ['Rank',
                                              'Team'])

rank_2017_df = pd.DataFrame(rank_2017)

rank_2017_df.head(25)
# Out:
#     Rank               Team
# 0      1            Clemson
# 1      2           Oklahoma
# 2      3            Georgia
# 3      4            Alabama
# 4      5         Ohio State
# 5      6          Wisconsin
# 6      7             Auburn
# 7      8       Southern Cal
# 8      9         Penn State
# 9     10              Miami
# 10    11         Washington
# 11    12    Central Florida
# 12    13           Stanford
# 13    14         Notre Dame
# 14    15                TCU
# 15    16     Michigan State
# 16    17                LSU
# 17    18   Washington State
# 18    19     Oklahoma State
# 19    20            Memphis
# 20    21       Northwestern
# 21    22      Virginia Tech
# 22    23  Mississippi State
# 23    24           NC State
# 24    25        Boise State

# %%
eada_2014 = "Resources/2014_eada.csv"

eada_2014 = pd.read_csv(eada_2014, usecols = ['Team',
                                              'Total Revenues', 
                                              'Total Expenses',
                                              'Net Revenue'])

eada_2014_df = pd.DataFrame(eada_2014)
eada_2014_df = eada_2014_df.sort_values("Net Revenue", ascending=False)


eada_2014_df.head(25)
# Out:
#                                                   Team  Total Revenues  \
# 60                   The University of Texas at Austin       121382436
# 59               The University of Tennessee-Knoxville        94377857
# 77                                             Georgia        86719115
# 27                                                 LSU        86312831
# 92                    University of Michigan-Ann Arbor        88251525
# 103                           University of Notre Dame        86125989
# 39                                          Ohio State        83547428
# 104               University of Oklahoma-Norman Campus        78737409
# 3                                               Auburn        86742256
# 58                                             Alabama        97023963
# 105                                             Oregon        60956894
# 19                                       Florida State        70321194
# 116            University of Washington-Seattle Campus        66941640
# 76                               University of Florida        74720732
# 54              Texas A & M University-College Station        62199166
# 44           Pennsylvania State University-Main Campus        71305219
# 69                              University of Arkansas        66179978
# 31                                      Michigan State        59227831
# 96                      University of Nebraska-Lincoln        60621628
# 108              University of South Carolina-Columbia        59768622
# 94                                            Ole Miss        53399653
# 82                                  University of Iowa        52354781
# 41               Oklahoma State University-Main Campus        43778793
# 121  Virginia Polytechnic Institute and State Unive...        50387116
# 114                                               Utah        42931079
#
#      Total Expenses  Net Revenue
# 60         29814804     91567632
# 59         24511032     69866825
# 77         26154335     60564780
# 27         28639663     57673168
# 92         31880547     56370978
# 103        31872250     54253739
# 39         32588493     50958935
# 104        30316609     48420800
# 3          40077352     46664904
# 58         51044292     45979671
# 105        20679336     40277558
# 19         31299768     39021426
# 116        29136569     37805071
# 76         37473203     37247529
# 54         25670784     36528382
# 44         35146623     36158596
# 69         30795322     35384656
# 31         27694367     31533464
# 96         29179492     31442136
# 108        31357215     28411407
# 94         25164361     28235292
# 82         25482299     26872482
# 41         19523281     24255512
# 121        26818875     23568241
# 114        19553655     23377424

# %%
eada_2015 = "Resources/2015_eada.csv"

eada_2015 = pd.read_csv(eada_2015, usecols = ['Team',
                                              'Total Revenues', 
                                              'Total Expenses',
                                              'Net Revenue'])

eada_2015_df = pd.DataFrame(eada_2015)
eada_2015_df = eada_2015_df.sort_values("Net Revenue", ascending=False)

eada_2015_df.head(51)
# Out:
#                                                   Team  Total Revenues  \
# 60                   The University of Texas at Austin       127465311
# 59                                           Tennessee       107103765
# 91                              University of Michigan        97149706
# 102                                         Notre Dame        98532894
# 103                                           Oklahoma        94142098
# 27                                                 LSU        85741919
# 75                                             Florida        83761070
# 3                                    Auburn University        92537433
# 39                                          Ohio State        86646061
# 76                               University of Georgia        87613126
# 58                                             Alabama       103870999
# 54              Texas A & M University-College Station        73700887
# 104                                             Oregon        66576139
# 116                    University of Wisconsin-Madison        71220684
# 44           Pennsylvania State University-Main Campus        75462597
# 95                      University of Nebraska-Lincoln        65012080
# 115            University of Washington-Seattle Campus        69134064
# 68                              University of Arkansas        68970599
# 31                                      Michigan State        64661163
# 107                       University of South Carolina        59629815
# 41                                      Oklahoma State        47760618
# 93                                            Ole Miss        56823049
# 81                                                Iowa        56551411
# 20         Georgia Institute of Technology-Main Campus        43605746
# 113                                               Utah        47685530
# 57                               Texas Tech University        42485160
# 92                 University of Minnesota-Twin Cities        49363392
# 36          North Carolina State University at Raleigh        39539832
# 25                             Kansas State University        38447972
# 109                                       Southern Cal        51240237
# 51                                            Stanford        43744639
# 67                               University of Arizona        41388363
# 69                   University of California-Berkeley        41527030
# 73                      University of Colorado Boulder        37544684
# 24                               Iowa State University        41789111
# 55                                                 TCU        52009661
# 83                              University of Kentucky        39714834
# 120  Virginia Polytechnic Institute and State Unive...        48433646
# 43                             Oregon State University        32941918
# 86                            University of Louisville        40568726
# 99                                      North Carolina        40523499
# 1                       Arizona State University-Tempe        42892151
# 82                                University of Kansas        30245133
# 122                        Washington State University        34457679
# 52                                 Syracuse University        38152217
# 80          University of Illinois at Urbana-Champaign        32910979
# 19                                       Florida State        55708828
# 33                        Mississippi State University        35471847
# 70                University of California-Los Angeles        38548482
# 38                                        Northwestern        36212907
# 12                                             Clemson        45930086
#
#      Total Expenses  Net Revenue
# 60         30268826     97196485
# 59         28158835     78944930
# 91         36597583     60552123
# 102        38971302     59561592
# 103        35854266     58287832
# 27         30463660     55278259
# 75         32048390     51712680
# 3          41896336     50641097
# 39         37378146     49267915
# 76         38884925     48728201
# 58         56214376     47656623
# 54         29945769     43755118
# 104        23768207     42807932
# 116        30731315     40489369
# 44         36163151     39299446
# 95         27493962     37518118
# 115        31811117     37322947
# 68         34237143     34733456
# 31         31978126     32683037
# 107        29970031     29659784
# 41         19445963     28314655
# 93         29500677     27322372
# 81         30150836     26400575
# 20         17375756     26229990
# 113        22044668     25640862
# 57         18039499     24445661
# 92         25542759     23820633
# 36         19194988     20344844
# 25         18361189     20086783
# 109        31186065     20054172
# 51         23724407     20020232
# 67         21399664     19988699
# 69         22079265     19447765
# 73         18372291     19172393
# 24         22764523     19024588
# 55         33471085     18538576
# 83         22309964     17404870
# 120        31150129     17283517
# 43         15745809     17196109
# 86         23428841     17139885
# 99         23461114     17062385
# 1          26601767     16290384
# 82         14011838     16233295
# 122        18430943     16026736
# 52         23219794     14932423
# 80         18242712     14668267
# 19         42457103     13251725
# 33         22311861     13159986
# 70         26735958     11812524
# 38         24629741     11583166
# 12         34668941     11261145

# %%
eada_2016 = "Resources/2016_eada.csv"

eada_2016 = pd.read_csv(eada_2016, usecols = ['Team',
                                              'Total Revenues', 
                                              'Total Expenses',
                                              'Net Revenue'])

eada_2016_df = pd.DataFrame(eada_2016)
eada_2016_df = eada_2016_df.sort_values("Net Revenue", ascending=False)

eada_2016_df.head(60)
# Out:
#                                             Team  Total Revenues  \
# 60             The University of Texas at Austin       141173444
# 59                                     Tennessee       110673571
# 102                     University of Notre Dame        96835375
# 91                                      Michigan       105876108
# 103                                     Oklahoma        95876446
# 76                         University of Georgia        93335288
# 27                                           LSU        86183249
# 39                                    Ohio State        89893135
# 75                                       Florida        82791752
# 3                                         Auburn        91652926
# 58                                       Alabama       108117057
# 115                                   Washington        80230690
# 44                                    Penn State        81106066
# 116                                    Wisconsin        73548409
# 54        Texas A & M University-College Station        70427183
# 31                     Michigan State University        64958793
# 19                                 Florida State        86565283
# 104                         University of Oregon        66307082
# 68                        University of Arkansas        71197898
# 95                University of Nebraska-Lincoln        69503006
# 93                     University of Mississippi        62681760
# 109                                 Southern Cal        59837839
# 120                                Virginia Tech        53471351
# 113                                         Utah        51559243
# 81                            University of Iowa        58685965
# 107        University of South Carolina-Columbia        60264364
# 20   Georgia Institute of Technology-Main Campus        46252310
# 57                         Texas Tech University        44646242
# 55                    Texas Christian University        58775636
# 67                         University of Arizona        44177156
# 41                                Oklahoma State        42225614
# 24                         Iowa State University        41584474
# 36    North Carolina State University at Raleigh        43165259
# 52                           Syracuse University        44182377
# 122                  Washington State University        40547097
# 73                                      Colorado        43529706
# 69             University of California-Berkeley        44279264
# 25                       Kansas State University        40887031
# 51                                      Stanford        44469378
# 99   University of North Carolina at Chapel Hill        41163583
# 92                       University of Minnesota        48886935
# 43                       Oregon State University        33866008
# 86                                    Louisville        42066595
# 82                          University of Kansas        33144217
# 80    University of Illinois at Urbana-Champaign        35622414
# 105                                         Pitt        40124656
# 70          University of California-Los Angeles        39953277
# 33                  Mississippi State University        35687282
# 38                       Northwestern University        38681564
# 1                 Arizona State University-Tempe        43012682
# 23                Indiana University-Bloomington        37085787
# 87           University of Maryland-College Park        29973008
# 83                        University of Kentucky        36393185
# 6                         Boise State University        21302390
# 5                              Baylor University        43223215
# 14                               Duke University        33907896
# 94               University of Missouri-Columbia        29205904
# 12                                       Clemson        51712856
# 9                 Brigham Young University-Provo        26116548
# 119                        Vanderbilt University        29036478
#
#      Total Expenses  Net Revenue
# 60         43306703     97866741
# 59         32600254     78073317
# 102        33257684     63577691
# 91         46249632     59626476
# 103        37848199     58028247
# 76         36387975     56947313
# 27         30086567     56096682
# 39         38446470     51446665
# 75         33692163     49099589
# 3          42825220     48827706
# 58         62252389     45864668
# 115        37660773     42569917
# 44         39163720     41942346
# 116        33147287     40401122
# 54         31078112     39349071
# 31         26326106     38632687
# 19         48330205     38235078
# 104        28912049     37395033
# 68         37326361     33871537
# 95         36571682     32931324
# 93         30410352     32271408
# 109        30184975     29652864
# 120        24995627     28475724
# 113        24483890     27075353
# 81         31800591     26885374
# 107        34794858     25469506
# 20         22349543     23902767
# 57         21460207     23186035
# 55         35716777     23058859
# 67         21138814     23038342
# 41         19321071     22904543
# 24         19177215     22407259
# 36         20866002     22299257
# 52         22039433     22142944
# 122        19053746     21493351
# 73         22126313     21403393
# 69         22909592     21369672
# 25         19889407     20997624
# 51         24606269     19863109
# 99         21670847     19492736
# 92         30950349     17936586
# 43         16354490     17511518
# 86         25194609     16871986
# 82         17061940     16082277
# 80         22332328     13290086
# 105        27421284     12703372
# 70         27320771     12632506
# 33         23069814     12617468
# 38         26751803     11929761
# 1          31371363     11641319
# 23         25672983     11412804
# 87         18908923     11064085
# 83         25589648     10803537
# 6          11141018     10161372
# 5          33370976      9852239
# 14         24492430      9415466
# 94         21093796      8112108
# 12         43943578      7769278
# 9          19253088      6863460
# 119        23316024      5720454

# %%
eada_2017 = "Resources/2017_eada.csv"

eada_2017 = pd.read_csv(eada_2017, usecols = ['Team',
                                              'Total Revenues', 
                                              'Total Expenses',
                                              'Net Revenue'])

eada_2017_df = pd.DataFrame(eada_2017)
eada_2017_df = eada_2017_df.sort_values("Net Revenue", ascending=False)
eada_2017_df.head(62)
# Out:
#                                   Team  Total Revenues  Total Expenses  \
# 60   The University of Texas at Austin       143064180        41250787
# 77                             Georgia       129023591        44909546
# 92    University of Michigan-Ann Arbor       124928493        43453382
# 103                         Notre Dame       107434072        42822063
# 39                          Ohio State       110661057        46444134
# ..                                 ...             ...             ...
# 70   University of California-Berkeley        32650505        25140854
# 120              Vanderbilt University        30331584        23476754
# 33                   Mississippi State        29753690        23226169
# 122             Wake Forest University        25793812        19360660
# 12                             Clemson        52029977        46302285
#
#      Net Revenue
# 60     101813393
# 77      84114045
# 92      81475111
# 103     64612009
# 39      64216923
# ..           ...
# 70       7509651
# 120      6854830
# 33       6527521
# 122      6433152
# 12       5727692
#
# [62 rows x 4 columns]

# %%
combined_2014 = pd.merge(rank_2014, eada_2014, on = "Team")
combined_2014.head(25)
# Out:
#     Rank               Team  Total Revenues  Total Expenses  Net Revenue
# 0      1            Alabama        97023963        51044292     45979671
# 1      2             Oregon        60956894        20679336     40277558
# 2      3      Florida State        70321194        31299768     39021426
# 3      4         Ohio State        83547428        32588493     50958935
# 4      5             Baylor        35575376        28433715      7141661
# 5      6                TCU        41259536        33751213      7508323
# 6      7  Mississippi State        31308423        17213521     14094902
# 7      8     Michigan State        59227831        27694367     31533464
# 8      9           Ole Miss        53399653        25164361     28235292
# 9     10            Arizona        23115960        20422820      2693140
# 10    11       Kansas State        34725916        16967110     17758806
# 11    12       Georgia Tech        41124340        19682945     21441395
# 12    13            Georgia        86719115        26154335     60564780
# 13    14               UCLA        44727001        26858792     17868209
# 14    15      Arizona State        49016140        28083384     20932756
# 15    16           Missouri        37892973        23318033     14574940
# 16    17            Clemson        43959747        24191774     19767973
# 17    18          Wisconsin        44797138        26643793     18153345
# 18    19             Auburn        86742256        40077352     46664904
# 19    20        Boise State        20206989         8839739     11367250
# 20    21         Louisville        36383759        18654530     17729229
# 21    22               Utah        42931079        19553655     23377424
# 22    23                LSU        86312831        28639663     57673168
# 23    24       Southern Cal        45886944        30575240     15311704
# 24    25          Minnesota        35772983        26292215      9480768

# %%
combined_2015 = pd.merge(rank_2015, eada_2015, on = "Team")
combined_2015.head(25)
# Out:
#     Rank            Team  Total Revenues  Total Expenses  Net Revenue
# 0    1.0         Clemson        45930086        34668941     11261145
# 1    2.0         Alabama       103870999        56214376     47656623
# 2    3.0  Michigan State        64661163        31978126     32683037
# 3    4.0        Oklahoma        94142098        35854266     58287832
# 4    5.0            Iowa        56551411        30150836     26400575
# 5    6.0        Stanford        43744639        23724407     20020232
# 6    7.0      Ohio State        86646061        37378146     49267915
# 7    8.0      Notre Dame        98532894        38971302     59561592
# 8    9.0   Florida State        55708828        42457103     13251725
# 9   10.0  North Carolina        40523499        23461114     17062385
# 10  11.0             TCU        52009661        33471085     18538576
# 11  12.0        Ole Miss        56823049        29500677     27322372
# 12  13.0    Northwestern        36212907        24629741     11583166
# 13  15.0          Oregon        66576139        23768207     42807932
# 14  16.0  Oklahoma State        47760618        19445963     28314655
# 15  17.0          Baylor        38305937        29544710      8761227
# 16  18.0         Houston        16180918        16180918            0
# 17  19.0         Florida        83761070        32048390     51712680
# 18  20.0             LSU        85741919        30463660     55278259
# 19  22.0            Utah        47685530        22044668     25640862
# 20  23.0       Tennessee       107103765        28158835     78944930
# 21  24.0          Temple        18842502        18842502            0
# 22  25.0    Southern Cal        51240237        31186065     20054172

# %%
combined_2016 = pd.merge(rank_2016, eada_2016, on = "Team")
combined_2016.head(25)
# Out:
#     Rank              Team  Total Revenues  Total Expenses  Net Revenue
# 0      1           Alabama       108117057        62252389     45864668
# 1      2           Clemson        51712856        43943578      7769278
# 2      3        Ohio State        89893135        38446470     51446665
# 3      4        Washington        80230690        37660773     42569917
# 4      5        Penn State        81106066        39163720     41942346
# 5      6          Michigan       105876108        46249632     59626476
# 6      7          Oklahoma        95876446        37848199     58028247
# 7      8         Wisconsin        73548409        33147287     40401122
# 8      9      Southern Cal        59837839        30184975     29652864
# 9     10          Colorado        43529706        22126313     21403393
# 10    11     Florida State        86565283        48330205     38235078
# 11    12    Oklahoma State        42225614        19321071     22904543
# 12    13        Louisville        42066595        25194609     16871986
# 13    14            Auburn        91652926        42825220     48827706
# 14    15  Western Michigan         8667334         8667334            0
# 15    16     West Virginia        22453097        20122095      2331002
# 16    17           Florida        82791752        33692163     49099589
# 17    18          Stanford        44469378        24606269     19863109
# 18    19              Utah        51559243        24483890     27075353
# 19    20               LSU        86183249        30086567     56096682
# 20    21         Tennessee       110673571        32600254     78073317
# 21    22     Virginia Tech        53471351        24995627     28475724
# 22    23              Pitt        40124656        27421284     12703372
# 23    24            Temple        20624125        20624125            0

# %%
combined_2017 = pd.merge(rank_2017, eada_2017, on = "Team")
combined_2017.head(25)
# Out:
#     Rank               Team  Total Revenues  Total Expenses  Net Revenue
# 0      1            Clemson        52029977        46302285      5727692
# 1      2           Oklahoma       102321307        39088102     63233205
# 2      3            Georgia       129023591        44909546     84114045
# 3      4            Alabama       111102134        62944472     48157662
# 4      5         Ohio State       110661057        46444134     64216923
# 5      6          Wisconsin        82423665        30153256     52270409
# 6      7             Auburn        93562715        43605320     49957395
# 7      8       Southern Cal        60171935        32949542     27222393
# 8      9         Penn State       100098956        45569892     54529064
# 9     10              Miami        57144810        37268190     19876620
# 10    11         Washington        81131079        38744975     42386104
# 11    12    Central Florida        26822661        21610325      5212336
# 12    13           Stanford        46847028        27000776     19846252
# 13    14         Notre Dame       107434072        42822063     64612009
# 14    15                TCU        56584276        39154002     17430274
# 15    16     Michigan State        77930837        33528479     44402358
# 16    17                LSU        86579944        31561996     55017948
# 17    18   Washington State        41709437        19963281     21746156
# 18    19     Oklahoma State        45717019        22467863     23249156
# 19    20            Memphis        17569774        17569774            0
# 20    21       Northwestern        49703674        30031305     19672369
# 21    22      Virginia Tech        55348135        27864229     27483906
# 22    23  Mississippi State        29753690        23226169      6527521
# 23    24           NC State        45214291        21321620     23892671
# 24    25        Boise State        20470985        11803457      8667528

# %%
plt.bar(combined_2014["Team"], 
        combined_2014["Net Revenue"], 
        align='center', 
        alpha=0.5)

plt.xlabel("CFP Top 25 Teams (1-25 left to right)")
plt.ylabel("Net Revenue in Millions")
plt.title("2014 Football Net Revenue")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
plt.bar(combined_2014["Team"], 
        combined_2014["Total Expenses"], 
        align='center', 
        alpha=0.5)

plt.xlabel("CFP Top 25 Teams")
plt.ylabel("Total Expense in Millions")
plt.title("2014 Total Annual Football Expenses")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
plt.bar(combined_2015["Team"], 
        combined_2015["Net Revenue"], 
        align='center', 
        alpha=0.5)

plt.xlabel("CFP Top 25 Teams (1-25 left to right)")
plt.ylabel("Net Revenue in Millions")
plt.title("2015 Football Net Revenue")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
plt.bar(combined_2015["Team"], 
        combined_2015["Total Expenses"], 
        align='center', 
        alpha=0.5)

plt.xlabel("CFP Top 25 Teams")
plt.ylabel("Total Expense in Millions")
plt.title("2015 Total Annual Football Expenses")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
plt.bar(combined_2016["Team"], 
        combined_2016["Net Revenue"], 
        align='center', 
        alpha=0.5)

plt.xlabel("CFP Top 25 Teams (1-25 left to right)")
plt.ylabel("Net Revenue in Millions")
plt.title("2016 Football Net Revenue")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
plt.bar(combined_2016["Team"], 
        combined_2016["Total Expenses"], 
        align='center', 
        alpha=0.5)

plt.xlabel("CFP Top 25 Teams")
plt.ylabel("Total Expense in Millions")
plt.title("2016 Total Annual Football Expenses")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
plt.bar(combined_2017["Team"], 
        combined_2017["Net Revenue"], 
        align='center', 
        alpha=0.5)

plt.xlabel("CFP Top 25 Teams (1-25 left to right)")
plt.ylabel("Net Revenue in Millions")
plt.title("2017 Football Net Revenue")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
plt.bar(combined_2017["Team"], 
        combined_2017["Total Expenses"], 
        align='center', 
        alpha=0.5)

plt.xlabel("CFP Top 25 Teams")
plt.ylabel("Total Expense in Millions")
plt.title("2017 Total Annual Football Expenses")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
stats_2014 = eada_2014.describe()
stats_2014
# Out:
#        Total Revenues  Total Expenses   Net Revenue
# count    1.270000e+02    1.270000e+02  1.270000e+02
# mean     2.947998e+07    1.682492e+07  1.265506e+07
# std      2.569457e+07    9.460914e+06  1.770456e+07
# min      3.397443e+06    3.397443e+06 -5.917615e+06
# 25%      8.212545e+06    8.016781e+06  0.000000e+00
# 50%      2.251049e+07    1.559820e+07  5.192975e+06
# 75%      4.156838e+07    2.372728e+07  1.823204e+07
# max      1.213824e+08    5.104429e+07  9.156763e+07

# %%
stats_2015 = eada_2015.describe()
stats_2015
# Out:
#        Total Revenues  Total Expenses   Net Revenue
# count    1.260000e+02    1.260000e+02  1.260000e+02
# mean     3.191044e+07    1.844164e+07  1.346880e+07
# std      2.768098e+07    1.049086e+07  1.885591e+07
# min      3.215000e+06    3.587178e+06 -9.640742e+06
# 25%      9.153630e+06    8.800689e+06  0.000000e+00
# 50%      2.380695e+07    1.732166e+07  4.487181e+06
# 75%      4.342735e+07    2.508465e+07  1.985347e+07
# max      1.274653e+08    5.621438e+07  9.719648e+07

# %%
stats_2016 = eada_2016.describe()
stats_2016
# Out:
#        Total Revenues  Total Expenses   Net Revenue
# count    1.260000e+02    1.260000e+02  1.260000e+02
# mean     3.385747e+07    1.992745e+07  1.393002e+07
# std      2.911279e+07    1.148616e+07  1.922529e+07
# min      5.110609e+06    4.193719e+06 -3.228756e+06
# 25%      9.749664e+06    9.726514e+06  0.000000e+00
# 50%      2.568018e+07    1.911548e+07  4.778853e+06
# 75%      4.442185e+07    2.673394e+07  2.238026e+07
# max      1.411734e+08    6.225239e+07  9.786674e+07

# %%
stats_2017 = eada_2017.describe()
stats_2017
# Out:
#        Total Revenues  Total Expenses   Net Revenue
# count    1.270000e+02    1.270000e+02  1.270000e+02
# mean     3.619540e+07    2.165895e+07  1.453644e+07
# std      3.190454e+07    1.332712e+07  2.086386e+07
# min      4.012412e+06    4.012412e+06 -6.873560e+06
# 25%      1.004501e+07    1.004501e+07  0.000000e+00
# 50%      2.593980e+07    2.003702e+07  3.820379e+06
# 75%      5.125379e+07    2.780949e+07  2.263575e+07
# max      1.430642e+08    6.294447e+07  1.018134e+08

# %%
x_values_2014 = eada_2014_df["Total Revenues"]
y_values_2014 = eada_2014_df["Total Expenses"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_values_2014.astype(float), y_values_2014.astype(float))

plt.title('Total Revenues and Total Expenses (2014)')
plt.ylabel('Total Expenses')
plt.xlabel('Total Revenues')
plt.scatter(x_values_2014, y_values_2014)
plt.plot(x_values_2014, intercept + slope * x_values_2014, 'r')
plt.annotate(f'$R^2$: {round(rvalue*rvalue,2)}', (14, 800), c = 'r', fontsize = 16)
plt.show()

# %%
ttest_2014 = scipy.stats.ttest_ind(eada_2014_df["Total Revenues"],
                                       eada_2014_df["Total Expenses"])

print(ttest_2014)
# Out:
# Ttest_indResult(statistic=5.2085472706871885, pvalue=3.957268339991969e-07)

# %%
x_values_2015 = eada_2015_df["Total Revenues"]
y_values_2015 = eada_2015_df["Total Expenses"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_values_2015.astype(float), y_values_2015.astype(float))

plt.title('Total Revenues and Total Expenses (2015)')
plt.ylabel('Total Expenses')
plt.xlabel('Total Revenues')
plt.scatter(x_values_2015, y_values_2015)
plt.plot(x_values_2015, intercept + slope * x_values_2015, 'r')
plt.annotate(f'$R^2$: {round(rvalue*rvalue,2)}', (14, 800), c = 'r', fontsize = 16)
plt.show()

# %%
ttest_2015 = scipy.stats.ttest_ind(eada_2015_df["Total Revenues"],
                                       eada_2015_df["Total Expenses"])

print(ttest_2015)
# Out:
# Ttest_indResult(statistic=5.107270906930852, pvalue=6.486049090789513e-07)

# %%
x_values_2016 = eada_2016_df["Total Revenues"]
y_values_2016 = eada_2016_df["Total Expenses"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_values_2016.astype(float), y_values_2016.astype(float))

plt.title('Total Revenues and Total Expenses (2016)')
plt.ylabel('Total Expenses')
plt.xlabel('Total Revenues')
plt.scatter(x_values_2016, y_values_2016)
plt.plot(x_values_2016, intercept + slope * x_values_2016, 'r')
plt.annotate(f'$R^2$: {round(rvalue*rvalue,2)}', (14, 800), c = 'r', fontsize = 16)
plt.show()

# %%
ttest_2016 = scipy.stats.ttest_ind(eada_2016_df["Total Revenues"],
                                       eada_2016_df["Total Expenses"])

print(ttest_2016)
# Out:
# Ttest_indResult(statistic=4.996177577471268, pvalue=1.0994381309899484e-06)

# %%
x_values_2017 = eada_2017_df["Total Revenues"]
y_values_2017 = eada_2017_df["Total Expenses"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_values_2017.astype(float), y_values_2017.astype(float))

plt.title('Total Revenues and Total Expenses (2017)')
plt.ylabel('Total Expenses')
plt.xlabel('Total Revenues')
plt.scatter(x_values_2017, y_values_2017)
plt.plot(x_values_2017, intercept + slope * x_values_2017, 'r')
plt.annotate(f'$R^2$: {round(rvalue*rvalue,2)}', (14, 800), c = 'r', fontsize = 16)
plt.show()

# %%
ttest_2017 = scipy.stats.ttest_ind(eada_2017_df["Total Revenues"],
                                       eada_2017_df["Total Expenses"])

print(ttest_2017)
# Out:
# Ttest_indResult(statistic=4.737869123134426, pvalue=3.6110260426913373e-06)
